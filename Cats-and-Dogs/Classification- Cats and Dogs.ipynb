# %%
#importing necessary packages
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
import tflearn
import tensorflow as tf
from PIL import Image
# %matplotlib inline
#for writing text files
import glob
import os     
import random 
#reading images from a text file
from tflearn.data_utils import image_preloader
import math

# %% [markdown]
# # Data processing

# %%
IMAGE_FOLDER = '/Users/Enkay/Documents/Viky/python/img-classification/train'
TRAIN_DATA = '/Users/Enkay/Documents/Viky/python/img-classification/training_data.txt'
TEST_DATA = '/Users/Enkay/Documents/Viky/python/img-classification/test_data.txt'
VALIDATION_DATA = '/Users/Enkay/Documents/Viky/python/img-classification/validation_data.txt'
train_proportion=0.7
test_proportion=0.2
validation_proportion=0.1

# %%
#read the image directories
filenames_image = os.listdir(IMAGE_FOLDER)
#shuffling the data is important otherwise the model will be fed with a single class data for a long time and 
#network will not learn properly
random.shuffle(filenames_image)

# %%
#total number of images
total=len(filenames_image)
##  *****training data******** 
fr = open(TRAIN_DATA, 'w')
train_files=filenames_image[0: int(train_proportion*total)]
for filename in train_files:
    if filename[0:3] == 'cat':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 0\n')
    elif filename[0:3] == 'dog':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 1\n')

fr.close()
##  *****testing data******** 
fr = open(TEST_DATA, 'w')
test_files=filenames_image[int(math.ceil(train_proportion*total)):int(math.ceil((train_proportion+test_proportion)*total))]
for filename in test_files:
    if filename[0:3] == 'cat':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 0\n')
    elif filename[0:3] == 'dog':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 1\n')
fr.close()

##  *****validation data******** 
fr = open(VALIDATION_DATA, 'w')
valid_files=filenames_image[int(math.ceil((train_proportion+test_proportion)*total)):total]
for filename in valid_files:
    if filename[0:3] == 'cat':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 0\n')
    elif filename[0:3] == 'dog':
        fr.write(IMAGE_FOLDER + '/'+ filename + ' 1\n')
fr.close()

# %%
#Importing data
#importing data
X_train, Y_train = image_preloader(TRAIN_DATA, image_shape=(56,56),mode='file', categorical_labels=True,normalize=True)
X_test, Y_test = image_preloader(TEST_DATA, image_shape=(56,56),mode='file', categorical_labels=True,normalize=True)
X_val, Y_val = image_preloader(VALIDATION_DATA, image_shape=(56,56),mode='file', categorical_labels=True,normalize=True)

# %%
print "Dataset"
print "Number of training images {}".format(len(X_train))
print "Number of testing images {}".format(len(X_test))
print "Number of validation images {}".format(len(X_val))
print "Shape of an image {}" .format(X_train[1].shape)
print "Shape of label:{} ,number of classes: {}".format(Y_train[1].shape,len(Y_train[1]))
# Out:
# Dataset
# Number of training images 17500
# Number of testing images 5000
# Number of validation images 2500
# Shape of an image (56, 56, 3)
# Shape of label:(2,) ,number of classes: 2

# %%
#Sample Image 
plt.imshow(X_train[1])
plt.axis('off')
plt.title('Sample image with label {}'.format(Y_train[1]))
plt.show()

# %% [markdown]
# # Model

# %%
x=tf.placeholder(tf.float32,shape=[None,56,56,3] , name='input_image') 
#input class
y_=tf.placeholder(tf.float32,shape=[None, 2] , name='input_class')

# %%
input_layer=x
#convolutional layer 1 --convolution+RELU activation
conv_layer1=tflearn.layers.conv.conv_2d(input_layer, nb_filter=64, filter_size=5, strides=[1,1,1,1],
                                        padding='same', activation='relu', regularizer="L2", name='conv_layer_1')

#2x2 max pooling layer
out_layer1=tflearn.layers.conv.max_pool_2d(conv_layer1, 2)


#second convolutional layer 
conv_layer2=tflearn.layers.conv.conv_2d(out_layer1, nb_filter=128, filter_size=5, strides=[1,1,1,1],
                                        padding='same', activation='relu',  regularizer="L2", name='conv_layer_2')
out_layer2=tflearn.layers.conv.max_pool_2d(conv_layer2, 2)
# third convolutional layer
conv_layer3=tflearn.layers.conv.conv_2d(out_layer2, nb_filter=128, filter_size=5, strides=[1,1,1,1],
                                        padding='same', activation='relu',  regularizer="L2", name='conv_layer_2')
out_layer3=tflearn.layers.conv.max_pool_2d(conv_layer3, 2)

#fully connected layer1
fcl= tflearn.layers.core.fully_connected(out_layer3, 4096, activation='relu' , name='FCL-1')
fcl_dropout_1 = tflearn.layers.core.dropout(fcl, 0.8)
#fully connected layer2
fc2= tflearn.layers.core.fully_connected(fcl_dropout_1, 4096, activation='relu' , name='FCL-2')
fcl_dropout_2 = tflearn.layers.core.dropout(fc2, 0.8)
#softmax layer output
y_predicted = tflearn.layers.core.fully_connected(fcl_dropout_2, 2, activation='softmax', name='output')

# %%
#loss function
cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(y_predicted+np.exp(-10)), reduction_indices=[1]))
#optimiser -
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
#calculating accuracy of our model 
correct_prediction = tf.equal(tf.argmax(y_predicted,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# session parameters
sess = tf.InteractiveSession()
#initialising variables
init = tf.initialize_all_variables()
sess.run(init)
saver = tf.train.Saver()
save_path="/Users/Enkay/Documents/Viky/python/img-classification/mark2.ckpt"

# %%
# grabbing the default graph
g = tf.get_default_graph()

# every operations in our graph
[op.name for op in g.get_operations()]
# Out:
# [u'is_training',
#  u'is_training/Initializer/Const',
#  u'is_training/Assign',
#  u'is_training/read',
#  u'Assign/value',
#  u'Assign',
#  u'Assign_1/value',
#  u'Assign_1',
#  u'input_image',
#  u'input_class',
#  u'conv_layer_1/W',
#  u'conv_layer_1/W/Initializer/random_uniform/shape',
#  u'conv_layer_1/W/Initializer/random_uniform/min',
#  u'conv_layer_1/W/Initializer/random_uniform/max',
#  u'conv_layer_1/W/Initializer/random_uniform/RandomUniform',
#  u'conv_layer_1/W/Initializer/random_uniform/sub',
#  u'conv_layer_1/W/Initializer/random_uniform/mul',
#  u'conv_layer_1/W/Initializer/random_uniform',
#  u'conv_layer_1/W/Assign',
#  u'conv_layer_1/W/read',
#  u'conv_layer_1/W/Regularizer/L2Loss',
#  u'conv_layer_1/W/Regularizer/L2-Loss/y',
#  u'conv_layer_1/W/Regularizer/L2-Loss',
#  u'conv_layer_1/b',
#  u'conv_layer_1/b/Initializer/Const',
#  u'conv_layer_1/b/Assign',
#  u'conv_layer_1/b/read',
#  u'conv_layer_1/Conv2D',
#  u'conv_layer_1/BiasAdd',
#  u'conv_layer_1/Relu',
#  u'MaxPool2D/MaxPool',
#  u'conv_layer_2/W',
#  u'conv_layer_2/W/Initializer/random_uniform/shape',
#  u'conv_layer_2/W/Initializer/random_uniform/min',
#  u'conv_layer_2/W/Initializer/random_uniform/max',
#  u'conv_layer_2/W/Initializer/random_uniform/RandomUniform',
#  u'conv_layer_2/W/Initializer/random_uniform/sub',
#  u'conv_layer_2/W/Initializer/random_uniform/mul',
#  u'conv_layer_2/W/Initializer/random_uniform',
#  u'conv_layer_2/W/Assign',
#  u'conv_layer_2/W/read',
#  u'conv_layer_2/W/Regularizer/L2Loss',
#  u'conv_layer_2/W/Regularizer/L2-Loss/y',
#  u'conv_layer_2/W/Regularizer/L2-Loss',
#  u'conv_layer_2/b',
#  u'conv_layer_2/b/Initializer/Const',
#  u'conv_layer_2/b/Assign',
#  u'conv_layer_2/b/read',
#  u'conv_layer_2/Conv2D',
#  u'conv_layer_2/BiasAdd',
#  u'conv_layer_2/Relu',
#  u'MaxPool2D_1/MaxPool',
#  u'conv_layer_2_1/W',
#  u'conv_layer_2_1/W/Initializer/random_uniform/shape',
#  u'conv_layer_2_1/W/Initializer/random_uniform/min',
#  u'conv_layer_2_1/W/Initializer/random_uniform/max',
#  u'conv_layer_2_1/W/Initializer/random_uniform/RandomUniform',
#  u'conv_layer_2_1/W/Initializer/random_uniform/sub',
#  u'conv_layer_2_1/W/Initializer/random_uniform/mul',
#  u'conv_layer_2_1/W/Initializer/random_uniform',
#  u'conv_layer_2_1/W/Assign',
#  u'conv_layer_2_1/W/read',
#  u'conv_layer_2_1/W/Regularizer/L2Loss',
#  u'conv_layer_2_1/W/Regularizer/L2-Loss/y',
#  u'conv_layer_2_1/W/Regularizer/L2-Loss',
#  u'conv_layer_2_1/b',
#  u'conv_layer_2_1/b/Initializer/Const',
#  u'conv_layer_2_1/b/Assign',
#  u'conv_layer_2_1/b/read',
#  u'conv_layer_2_1/Conv2D',
#  u'conv_layer_2_1/BiasAdd',
#  u'conv_layer_2_1/Relu',
#  u'MaxPool2D_2/MaxPool',
#  u'FCL-1/W',
#  u'FCL-1/W/Initializer/truncated_normal/shape',
#  u'FCL-1/W/Initializer/truncated_normal/mean',
#  u'FCL-1/W/Initializer/truncated_normal/stddev',
#  u'FCL-1/W/Initializer/truncated_normal/TruncatedNormal',
#  u'FCL-1/W/Initializer/truncated_normal/mul',
#  u'FCL-1/W/Initializer/truncated_normal',
#  u'FCL-1/W/Assign',
#  u'FCL-1/W/read',
#  u'FCL-1/b',
#  u'FCL-1/b/Initializer/Const',
#  u'FCL-1/b/Assign',
#  u'FCL-1/b/read',
#  u'FCL-1/Reshape/shape',
#  u'FCL-1/Reshape',
#  u'FCL-1/MatMul',
#  u'FCL-1/BiasAdd',
#  u'FCL-1/Relu',
#  u'Dropout/cond/Switch',
#  u'Dropout/cond/switch_t',
#  u'Dropout/cond/switch_f',
#  u'Dropout/cond/pred_id',
#  u'Dropout/cond/dropout/keep_prob',
#  u'Dropout/cond/dropout/Shape/Switch',
#  u'Dropout/cond/dropout/Shape',
#  u'Dropout/cond/dropout/random_uniform/min',
#  u'Dropout/cond/dropout/random_uniform/max',
#  u'Dropout/cond/dropout/random_uniform/RandomUniform',
#  u'Dropout/cond/dropout/random_uniform/sub',
#  u'Dropout/cond/dropout/random_uniform/mul',
#  u'Dropout/cond/dropout/random_uniform',
#  u'Dropout/cond/dropout/add',
#  u'Dropout/cond/dropout/Floor',
#  u'Dropout/cond/dropout/Div',
#  u'Dropout/cond/dropout/mul',
#  u'Dropout/cond/Switch_1',
#  u'Dropout/cond/Merge',
#  u'FCL-2/W',
#  u'FCL-2/W/Initializer/truncated_normal/shape',
#  u'FCL-2/W/Initializer/truncated_normal/mean',
#  u'FCL-2/W/Initializer/truncated_normal/stddev',
#  u'FCL-2/W/Initializer/truncated_normal/TruncatedNormal',
#  u'FCL-2/W/Initializer/truncated_normal/mul',
#  u'FCL-2/W/Initializer/truncated_normal',
#  u'FCL-2/W/Assign',
#  u'FCL-2/W/read',
#  u'FCL-2/b',
#  u'FCL-2/b/Initializer/Const',
#  u'FCL-2/b/Assign',
#  u'FCL-2/b/read',
#  u'FCL-2/MatMul',
#  u'FCL-2/BiasAdd',
#  u'FCL-2/Relu',
#  u'Dropout_1/cond/Switch',
#  u'Dropout_1/cond/switch_t',
#  u'Dropout_1/cond/switch_f',
#  u'Dropout_1/cond/pred_id',
#  u'Dropout_1/cond/dropout/keep_prob',
#  u'Dropout_1/cond/dropout/Shape/Switch',
#  u'Dropout_1/cond/dropout/Shape',
#  u'Dropout_1/cond/dropout/random_uniform/min',
#  u'Dropout_1/cond/dropout/random_uniform/max',
#  u'Dropout_1/cond/dropout/random_uniform/RandomUniform',
#  u'Dropout_1/cond/dropout/random_uniform/sub',
#  u'Dropout_1/cond/dropout/random_uniform/mul',
#  u'Dropout_1/cond/dropout/random_uniform',
#  u'Dropout_1/cond/dropout/add',
#  u'Dropout_1/cond/dropout/Floor',
#  u'Dropout_1/cond/dropout/Div',
#  u'Dropout_1/cond/dropout/mul',
#  u'Dropout_1/cond/Switch_1',
#  u'Dropout_1/cond/Merge',
#  u'output/W',
#  u'output/W/Initializer/truncated_normal/shape',
#  u'output/W/Initializer/truncated_normal/mean',
#  u'output/W/Initializer/truncated_normal/stddev',
#  u'output/W/Initializer/truncated_normal/TruncatedNormal',
#  u'output/W/Initializer/truncated_normal/mul',
#  u'output/W/Initializer/truncated_normal',
#  u'output/W/Assign',
#  u'output/W/read',
#  u'output/b',
#  u'output/b/Initializer/Const',
#  u'output/b/Assign',
#  u'output/b/read',
#  u'output/MatMul',
#  u'output/BiasAdd',
#  u'output/Softmax',
#  u'add/y',
#  u'add',
#  u'Log',
#  u'mul',
#  u'Sum/reduction_indices',
#  u'Sum',
#  u'Neg',
#  u'Const',
#  u'Mean',
#  u'gradients/Shape',
#  u'gradients/Const',
#  u'gradients/Fill',
#  u'gradients/Mean_grad/Reshape/shape',
#  u'gradients/Mean_grad/Reshape',
#  u'gradients/Mean_grad/Shape',
#  u'gradients/Mean_grad/Tile',
#  u'gradients/Mean_grad/Shape_1',
#  u'gradients/Mean_grad/Shape_2',
#  u'gradients/Mean_grad/Const',
#  u'gradients/Mean_grad/Prod',
#  u'gradients/Mean_grad/Const_1',
#  u'gradients/Mean_grad/Prod_1',
#  u'gradients/Mean_grad/Maximum/y',
#  u'gradients/Mean_grad/Maximum',
#  u'gradients/Mean_grad/floordiv',
#  u'gradients/Mean_grad/Cast',
#  u'gradients/Mean_grad/truediv',
#  u'gradients/Neg_grad/Neg',
#  u'gradients/Sum_grad/Shape',
#  u'gradients/Sum_grad/Size',
#  u'gradients/Sum_grad/add',
#  u'gradients/Sum_grad/mod',
#  u'gradients/Sum_grad/Shape_1',
#  u'gradients/Sum_grad/range/start',
#  u'gradients/Sum_grad/range/delta',
#  u'gradients/Sum_grad/range',
#  u'gradients/Sum_grad/Fill/value',
#  u'gradients/Sum_grad/Fill',
#  u'gradients/Sum_grad/DynamicStitch',
#  u'gradients/Sum_grad/Maximum/y',
#  u'gradients/Sum_grad/Maximum',
#  u'gradients/Sum_grad/floordiv',
#  u'gradients/Sum_grad/Reshape',
#  u'gradients/Sum_grad/Tile',
#  u'gradients/mul_grad/Shape',
#  u'gradients/mul_grad/Shape_1',
#  u'gradients/mul_grad/BroadcastGradientArgs',
#  u'gradients/mul_grad/mul',
#  u'gradients/mul_grad/Sum',
#  u'gradients/mul_grad/Reshape',
#  u'gradients/mul_grad/mul_1',
#  u'gradients/mul_grad/Sum_1',
#  u'gradients/mul_grad/Reshape_1',
#  u'gradients/mul_grad/tuple/group_deps',
#  u'gradients/mul_grad/tuple/control_dependency',
#  u'gradients/mul_grad/tuple/control_dependency_1',
#  u'gradients/Log_grad/Inv',
#  u'gradients/Log_grad/mul',
#  u'gradients/add_grad/Shape',
#  u'gradients/add_grad/Shape_1',
#  u'gradients/add_grad/BroadcastGradientArgs',
#  u'gradients/add_grad/Sum',
#  u'gradients/add_grad/Reshape',
#  u'gradients/add_grad/Sum_1',
#  u'gradients/add_grad/Reshape_1',
#  u'gradients/add_grad/tuple/group_deps',
#  u'gradients/add_grad/tuple/control_dependency',
#  u'gradients/add_grad/tuple/control_dependency_1',
#  u'gradients/output/Softmax_grad/mul',
#  u'gradients/output/Softmax_grad/Sum/reduction_indices',
#  u'gradients/output/Softmax_grad/Sum',
#  u'gradients/output/Softmax_grad/Reshape/shape',
#  u'gradients/output/Softmax_grad/Reshape',
#  u'gradients/output/Softmax_grad/sub',
#  u'gradients/output/Softmax_grad/mul_1',
#  u'gradients/output/BiasAdd_grad/BiasAddGrad',
#  u'gradients/output/BiasAdd_grad/tuple/group_deps',
#  u'gradients/output/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/output/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/output/MatMul_grad/MatMul',
#  u'gradients/output/MatMul_grad/MatMul_1',
#  u'gradients/output/MatMul_grad/tuple/group_deps',
#  u'gradients/output/MatMul_grad/tuple/control_dependency',
#  u'gradients/output/MatMul_grad/tuple/control_dependency_1',
#  u'gradients/Dropout_1/cond/Merge_grad/cond_grad',
#  u'gradients/Dropout_1/cond/Merge_grad/tuple/group_deps',
#  u'gradients/Dropout_1/cond/Merge_grad/tuple/control_dependency',
#  u'gradients/Dropout_1/cond/Merge_grad/tuple/control_dependency_1',
#  u'gradients/Switch',
#  u'gradients/Shape_1',
#  u'gradients/zeros/Const',
#  u'gradients/zeros',
#  u'gradients/Dropout_1/cond/Switch_1_grad/cond_grad',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Shape',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Shape_1',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/BroadcastGradientArgs',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/mul',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Sum',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Reshape',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/mul_1',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Sum_1',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/Reshape_1',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/tuple/group_deps',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/tuple/control_dependency',
#  u'gradients/Dropout_1/cond/dropout/mul_grad/tuple/control_dependency_1',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Shape',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Shape_1',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/BroadcastGradientArgs',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/truediv',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Sum',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Reshape',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Neg',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Square',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/truediv_1',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/mul',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Sum_1',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/Reshape_1',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/tuple/group_deps',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/tuple/control_dependency',
#  u'gradients/Dropout_1/cond/dropout/Div_grad/tuple/control_dependency_1',
#  u'gradients/Switch_1',
#  u'gradients/Shape_2',
#  u'gradients/zeros_1/Const',
#  u'gradients/zeros_1',
#  u'gradients/Dropout_1/cond/dropout/Shape/Switch_grad/cond_grad',
#  u'gradients/AddN',
#  u'gradients/FCL-2/Relu_grad/ReluGrad',
#  u'gradients/FCL-2/BiasAdd_grad/BiasAddGrad',
#  u'gradients/FCL-2/BiasAdd_grad/tuple/group_deps',
#  u'gradients/FCL-2/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/FCL-2/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/FCL-2/MatMul_grad/MatMul',
#  u'gradients/FCL-2/MatMul_grad/MatMul_1',
#  u'gradients/FCL-2/MatMul_grad/tuple/group_deps',
#  u'gradients/FCL-2/MatMul_grad/tuple/control_dependency',
#  u'gradients/FCL-2/MatMul_grad/tuple/control_dependency_1',
#  u'gradients/Dropout/cond/Merge_grad/cond_grad',
#  u'gradients/Dropout/cond/Merge_grad/tuple/group_deps',
#  u'gradients/Dropout/cond/Merge_grad/tuple/control_dependency',
#  u'gradients/Dropout/cond/Merge_grad/tuple/control_dependency_1',
#  u'gradients/Switch_2',
#  u'gradients/Shape_3',
#  u'gradients/zeros_2/Const',
#  u'gradients/zeros_2',
#  u'gradients/Dropout/cond/Switch_1_grad/cond_grad',
#  u'gradients/Dropout/cond/dropout/mul_grad/Shape',
#  u'gradients/Dropout/cond/dropout/mul_grad/Shape_1',
#  u'gradients/Dropout/cond/dropout/mul_grad/BroadcastGradientArgs',
#  u'gradients/Dropout/cond/dropout/mul_grad/mul',
#  u'gradients/Dropout/cond/dropout/mul_grad/Sum',
#  u'gradients/Dropout/cond/dropout/mul_grad/Reshape',
#  u'gradients/Dropout/cond/dropout/mul_grad/mul_1',
#  u'gradients/Dropout/cond/dropout/mul_grad/Sum_1',
#  u'gradients/Dropout/cond/dropout/mul_grad/Reshape_1',
#  u'gradients/Dropout/cond/dropout/mul_grad/tuple/group_deps',
#  u'gradients/Dropout/cond/dropout/mul_grad/tuple/control_dependency',
#  u'gradients/Dropout/cond/dropout/mul_grad/tuple/control_dependency_1',
#  u'gradients/Dropout/cond/dropout/Div_grad/Shape',
#  u'gradients/Dropout/cond/dropout/Div_grad/Shape_1',
#  u'gradients/Dropout/cond/dropout/Div_grad/BroadcastGradientArgs',
#  u'gradients/Dropout/cond/dropout/Div_grad/truediv',
#  u'gradients/Dropout/cond/dropout/Div_grad/Sum',
#  u'gradients/Dropout/cond/dropout/Div_grad/Reshape',
#  u'gradients/Dropout/cond/dropout/Div_grad/Neg',
#  u'gradients/Dropout/cond/dropout/Div_grad/Square',
#  u'gradients/Dropout/cond/dropout/Div_grad/truediv_1',
#  u'gradients/Dropout/cond/dropout/Div_grad/mul',
#  u'gradients/Dropout/cond/dropout/Div_grad/Sum_1',
#  u'gradients/Dropout/cond/dropout/Div_grad/Reshape_1',
#  u'gradients/Dropout/cond/dropout/Div_grad/tuple/group_deps',
#  u'gradients/Dropout/cond/dropout/Div_grad/tuple/control_dependency',
#  u'gradients/Dropout/cond/dropout/Div_grad/tuple/control_dependency_1',
#  u'gradients/Switch_3',
#  u'gradients/Shape_4',
#  u'gradients/zeros_3/Const',
#  u'gradients/zeros_3',
#  u'gradients/Dropout/cond/dropout/Shape/Switch_grad/cond_grad',
#  u'gradients/AddN_1',
#  u'gradients/FCL-1/Relu_grad/ReluGrad',
#  u'gradients/FCL-1/BiasAdd_grad/BiasAddGrad',
#  u'gradients/FCL-1/BiasAdd_grad/tuple/group_deps',
#  u'gradients/FCL-1/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/FCL-1/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/FCL-1/MatMul_grad/MatMul',
#  u'gradients/FCL-1/MatMul_grad/MatMul_1',
#  u'gradients/FCL-1/MatMul_grad/tuple/group_deps',
#  u'gradients/FCL-1/MatMul_grad/tuple/control_dependency',
#  u'gradients/FCL-1/MatMul_grad/tuple/control_dependency_1',
#  u'gradients/FCL-1/Reshape_grad/Shape',
#  u'gradients/FCL-1/Reshape_grad/Reshape',
#  u'gradients/MaxPool2D_2/MaxPool_grad/MaxPoolGrad',
#  u'gradients/conv_layer_2_1/Relu_grad/ReluGrad',
#  u'gradients/conv_layer_2_1/BiasAdd_grad/BiasAddGrad',
#  u'gradients/conv_layer_2_1/BiasAdd_grad/tuple/group_deps',
#  u'gradients/conv_layer_2_1/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/conv_layer_2_1/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/conv_layer_2_1/Conv2D_grad/Shape',
#  u'gradients/conv_layer_2_1/Conv2D_grad/Conv2DBackpropInput',
#  u'gradients/conv_layer_2_1/Conv2D_grad/Shape_1',
#  u'gradients/conv_layer_2_1/Conv2D_grad/Conv2DBackpropFilter',
#  u'gradients/conv_layer_2_1/Conv2D_grad/tuple/group_deps',
#  u'gradients/conv_layer_2_1/Conv2D_grad/tuple/control_dependency',
#  u'gradients/conv_layer_2_1/Conv2D_grad/tuple/control_dependency_1',
#  u'gradients/MaxPool2D_1/MaxPool_grad/MaxPoolGrad',
#  u'gradients/conv_layer_2/Relu_grad/ReluGrad',
#  u'gradients/conv_layer_2/BiasAdd_grad/BiasAddGrad',
#  u'gradients/conv_layer_2/BiasAdd_grad/tuple/group_deps',
#  u'gradients/conv_layer_2/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/conv_layer_2/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/conv_layer_2/Conv2D_grad/Shape',
#  u'gradients/conv_layer_2/Conv2D_grad/Conv2DBackpropInput',
#  u'gradients/conv_layer_2/Conv2D_grad/Shape_1',
#  u'gradients/conv_layer_2/Conv2D_grad/Conv2DBackpropFilter',
#  u'gradients/conv_layer_2/Conv2D_grad/tuple/group_deps',
#  u'gradients/conv_layer_2/Conv2D_grad/tuple/control_dependency',
#  u'gradients/conv_layer_2/Conv2D_grad/tuple/control_dependency_1',
#  u'gradients/MaxPool2D/MaxPool_grad/MaxPoolGrad',
#  u'gradients/conv_layer_1/Relu_grad/ReluGrad',
#  u'gradients/conv_layer_1/BiasAdd_grad/BiasAddGrad',
#  u'gradients/conv_layer_1/BiasAdd_grad/tuple/group_deps',
#  u'gradients/conv_layer_1/BiasAdd_grad/tuple/control_dependency',
#  u'gradients/conv_layer_1/BiasAdd_grad/tuple/control_dependency_1',
#  u'gradients/conv_layer_1/Conv2D_grad/Shape',
#  u'gradients/conv_layer_1/Conv2D_grad/Conv2DBackpropInput',
#  u'gradients/conv_layer_1/Conv2D_grad/Shape_1',
#  u'gradients/conv_layer_1/Conv2D_grad/Conv2DBackpropFilter',
#  u'gradients/conv_layer_1/Conv2D_grad/tuple/group_deps',
#  u'gradients/conv_layer_1/Conv2D_grad/tuple/control_dependency',
#  u'gradients/conv_layer_1/Conv2D_grad/tuple/control_dependency_1',
#  u'beta1_power/initial_value',
#  u'beta1_power',
#  u'beta1_power/Assign',
#  u'beta1_power/read',
#  u'beta2_power/initial_value',
#  u'beta2_power',
#  u'beta2_power/Assign',
#  u'beta2_power/read',
#  u'zeros',
#  u'conv_layer_1/W/Adam',
#  u'conv_layer_1/W/Adam/Assign',
#  u'conv_layer_1/W/Adam/read',
#  u'zeros_1',
#  u'conv_layer_1/W/Adam_1',
#  u'conv_layer_1/W/Adam_1/Assign',
#  u'conv_layer_1/W/Adam_1/read',
#  u'zeros_2',
#  u'conv_layer_1/b/Adam',
#  u'conv_layer_1/b/Adam/Assign',
#  u'conv_layer_1/b/Adam/read',
#  u'zeros_3',
#  u'conv_layer_1/b/Adam_1',
#  u'conv_layer_1/b/Adam_1/Assign',
#  u'conv_layer_1/b/Adam_1/read',
#  u'zeros_4',
#  u'conv_layer_2/W/Adam',
#  u'conv_layer_2/W/Adam/Assign',
#  u'conv_layer_2/W/Adam/read',
#  u'zeros_5',
#  u'conv_layer_2/W/Adam_1',
#  u'conv_layer_2/W/Adam_1/Assign',
#  u'conv_layer_2/W/Adam_1/read',
#  u'zeros_6',
#  u'conv_layer_2/b/Adam',
#  u'conv_layer_2/b/Adam/Assign',
#  u'conv_layer_2/b/Adam/read',
#  u'zeros_7',
#  u'conv_layer_2/b/Adam_1',
#  u'conv_layer_2/b/Adam_1/Assign',
#  u'conv_layer_2/b/Adam_1/read',
#  u'zeros_8',
#  u'conv_layer_2_1/W/Adam',
#  u'conv_layer_2_1/W/Adam/Assign',
#  u'conv_layer_2_1/W/Adam/read',
#  u'zeros_9',
#  u'conv_layer_2_1/W/Adam_1',
#  u'conv_layer_2_1/W/Adam_1/Assign',
#  u'conv_layer_2_1/W/Adam_1/read',
#  u'zeros_10',
#  u'conv_layer_2_1/b/Adam',
#  u'conv_layer_2_1/b/Adam/Assign',
#  u'conv_layer_2_1/b/Adam/read',
#  u'zeros_11',
#  u'conv_layer_2_1/b/Adam_1',
#  u'conv_layer_2_1/b/Adam_1/Assign',
#  u'conv_layer_2_1/b/Adam_1/read',
#  u'zeros_12',
#  u'FCL-1/W/Adam',
#  u'FCL-1/W/Adam/Assign',
#  u'FCL-1/W/Adam/read',
#  u'zeros_13',
#  u'FCL-1/W/Adam_1',
#  u'FCL-1/W/Adam_1/Assign',
#  u'FCL-1/W/Adam_1/read',
#  u'zeros_14',
#  u'FCL-1/b/Adam',
#  u'FCL-1/b/Adam/Assign',
#  u'FCL-1/b/Adam/read',
#  u'zeros_15',
#  u'FCL-1/b/Adam_1',
#  u'FCL-1/b/Adam_1/Assign',
#  u'FCL-1/b/Adam_1/read',
#  u'zeros_16',
#  u'FCL-2/W/Adam',
#  u'FCL-2/W/Adam/Assign',
#  u'FCL-2/W/Adam/read',
#  u'zeros_17',
#  u'FCL-2/W/Adam_1',
#  u'FCL-2/W/Adam_1/Assign',
#  u'FCL-2/W/Adam_1/read',
#  u'zeros_18',
#  u'FCL-2/b/Adam',
#  u'FCL-2/b/Adam/Assign',
#  u'FCL-2/b/Adam/read',
#  u'zeros_19',
#  u'FCL-2/b/Adam_1',
#  u'FCL-2/b/Adam_1/Assign',
#  u'FCL-2/b/Adam_1/read',
#  u'zeros_20',
#  u'output/W/Adam',
#  u'output/W/Adam/Assign',
#  u'output/W/Adam/read',
#  u'zeros_21',
#  u'output/W/Adam_1',
#  u'output/W/Adam_1/Assign',
#  u'output/W/Adam_1/read',
#  u'zeros_22',
#  u'output/b/Adam',
#  u'output/b/Adam/Assign',
#  u'output/b/Adam/read',
#  u'zeros_23',
#  u'output/b/Adam_1',
#  u'output/b/Adam_1/Assign',
#  u'output/b/Adam_1/read',
#  u'Adam/learning_rate',
#  u'Adam/beta1',
#  u'Adam/beta2',
#  u'Adam/epsilon',
#  u'Adam/update_conv_layer_1/W/ApplyAdam',
#  u'Adam/update_conv_layer_1/b/ApplyAdam',
#  u'Adam/update_conv_layer_2/W/ApplyAdam',
#  u'Adam/update_conv_layer_2/b/ApplyAdam',
#  u'Adam/update_conv_layer_2_1/W/ApplyAdam',
#  u'Adam/update_conv_layer_2_1/b/ApplyAdam',
#  u'Adam/update_FCL-1/W/ApplyAdam',
#  u'Adam/update_FCL-1/b/ApplyAdam',
#  u'Adam/update_FCL-2/W/ApplyAdam',
#  u'Adam/update_FCL-2/b/ApplyAdam',
#  u'Adam/update_output/W/ApplyAdam',
#  u'Adam/update_output/b/ApplyAdam',
#  u'Adam/mul',
#  u'Adam/Assign',
#  u'Adam/mul_1',
#  u'Adam/Assign_1',
#  u'Adam',
#  u'ArgMax/dimension',
#  u'ArgMax',
#  u'ArgMax_1/dimension',
#  u'ArgMax_1',
#  u'Equal',
#  u'Cast',
#  u'Const_1',
#  u'Mean_1',
#  u'init',
#  u'save/Const',
#  u'save/save/tensor_names',
#  u'save/save/shapes_and_slices',
#  u'save/save',
#  u'save/control_dependency',
#  u'save/restore_slice/tensor_name',
#  u'save/restore_slice/shape_and_slice',
#  u'save/restore_slice',
#  u'save/Assign',
#  u'save/restore_slice_1/tensor_name',
#  u'save/restore_slice_1/shape_and_slice',
#  u'save/restore_slice_1',
#  u'save/Assign_1',
#  u'save/restore_slice_2/tensor_name',
#  u'save/restore_slice_2/shape_and_slice',
#  u'save/restore_slice_2',
#  u'save/Assign_2',
#  u'save/restore_slice_3/tensor_name',
#  u'save/restore_slice_3/shape_and_slice',
#  u'save/restore_slice_3',
#  u'save/Assign_3',
#  u'save/restore_slice_4/tensor_name',
#  u'save/restore_slice_4/shape_and_slice',
#  u'save/restore_slice_4',
#  u'save/Assign_4',
#  u'save/restore_slice_5/tensor_name',
#  u'save/restore_slice_5/shape_and_slice',
#  u'save/restore_slice_5',
#  u'save/Assign_5',
#  u'save/restore_slice_6/tensor_name',
#  u'save/restore_slice_6/shape_and_slice',
#  u'save/restore_slice_6',
#  u'save/Assign_6',
#  u'save/restore_slice_7/tensor_name',
#  u'save/restore_slice_7/shape_and_slice',
#  u'save/restore_slice_7',
#  u'save/Assign_7',
#  u'save/restore_slice_8/tensor_name',
#  u'save/restore_slice_8/shape_and_slice',
#  u'save/restore_slice_8',
#  u'save/Assign_8',
#  u'save/restore_slice_9/tensor_name',
#  u'save/restore_slice_9/shape_and_slice',
#  u'save/restore_slice_9',
#  u'save/Assign_9',
#  u'save/restore_slice_10/tensor_name',
#  u'save/restore_slice_10/shape_and_slice',
#  u'save/restore_slice_10',
#  u'save/Assign_10',
#  u'save/restore_slice_11/tensor_name',
#  u'save/restore_slice_11/shape_and_slice',
#  u'save/restore_slice_11',
#  u'save/Assign_11',
#  u'save/restore_slice_12/tensor_name',
#  u'save/restore_slice_12/shape_and_slice',
#  u'save/restore_slice_12',
#  u'save/Assign_12',
#  u'save/restore_slice_13/tensor_name',
#  u'save/restore_slice_13/shape_and_slice',
#  u'save/restore_slice_13',
#  u'save/Assign_13',
#  u'save/restore_slice_14/tensor_name',
#  u'save/restore_slice_14/shape_and_slice',
#  u'save/restore_slice_14',
#  u'save/Assign_14',
#  u'save/restore_slice_15/tensor_name',
#  u'save/restore_slice_15/shape_and_slice',
#  u'save/restore_slice_15',
#  u'save/Assign_15',
#  u'save/restore_slice_16/tensor_name',
#  u'save/restore_slice_16/shape_and_slice',
#  u'save/restore_slice_16',
#  u'save/Assign_16',
#  u'save/restore_slice_17/tensor_name',
#  u'save/restore_slice_17/shape_and_slice',
#  u'save/restore_slice_17',
#  u'save/Assign_17',
#  u'save/restore_slice_18/tensor_name',
#  u'save/restore_slice_18/shape_and_slice',
#  u'save/restore_slice_18',
#  u'save/Assign_18',
#  u'save/restore_slice_19/tensor_name',
#  u'save/restore_slice_19/shape_and_slice',
#  u'save/restore_slice_19',
#  u'save/Assign_19',
#  u'save/restore_slice_20/tensor_name',
#  u'save/restore_slice_20/shape_and_slice',
#  u'save/restore_slice_20',
#  u'save/Assign_20',
#  u'save/restore_slice_21/tensor_name',
#  u'save/restore_slice_21/shape_and_slice',
#  u'save/restore_slice_21',
#  u'save/Assign_21',
#  u'save/restore_slice_22/tensor_name',
#  u'save/restore_slice_22/shape_and_slice',
#  u'save/restore_slice_22',
#  u'save/Assign_22',
#  u'save/restore_slice_23/tensor_name',
#  u'save/restore_slice_23/shape_and_slice',
#  u'save/restore_slice_23',
#  u'save/Assign_23',
#  u'save/restore_slice_24/tensor_name',
#  u'save/restore_slice_24/shape_and_slice',
#  u'save/restore_slice_24',
#  u'save/Assign_24',
#  u'save/restore_slice_25/tensor_name',
#  u'save/restore_slice_25/shape_and_slice',
#  u'save/restore_slice_25',
#  u'save/Assign_25',
#  u'save/restore_slice_26/tensor_name',
#  u'save/restore_slice_26/shape_and_slice',
#  u'save/restore_slice_26',
#  u'save/Assign_26',
#  u'save/restore_slice_27/tensor_name',
#  u'save/restore_slice_27/shape_and_slice',
#  u'save/restore_slice_27',
#  u'save/Assign_27',
#  u'save/restore_slice_28/tensor_name',
#  u'save/restore_slice_28/shape_and_slice',
#  u'save/restore_slice_28',
#  u'save/Assign_28',
#  u'save/restore_slice_29/tensor_name',
#  u'save/restore_slice_29/shape_and_slice',
#  u'save/restore_slice_29',
#  u'save/Assign_29',
#  u'save/restore_slice_30/tensor_name',
#  u'save/restore_slice_30/shape_and_slice',
#  u'save/restore_slice_30',
#  u'save/Assign_30',
#  u'save/restore_slice_31/tensor_name',
#  u'save/restore_slice_31/shape_and_slice',
#  u'save/restore_slice_31',
#  u'save/Assign_31',
#  u'save/restore_slice_32/tensor_name',
#  u'save/restore_slice_32/shape_and_slice',
#  u'save/restore_slice_32',
#  u'save/Assign_32',
#  u'save/restore_slice_33/tensor_name',
#  u'save/restore_slice_33/shape_and_slice',
#  u'save/restore_slice_33',
#  u'save/Assign_33',
#  u'save/restore_slice_34/tensor_name',
#  u'save/restore_slice_34/shape_and_slice',
#  u'save/restore_slice_34',
#  u'save/Assign_34',
#  u'save/restore_slice_35/tensor_name',
#  u'save/restore_slice_35/shape_and_slice',
#  u'save/restore_slice_35',
#  u'save/Assign_35',
#  u'save/restore_slice_36/tensor_name',
#  u'save/restore_slice_36/shape_and_slice',
#  u'save/restore_slice_36',
#  u'save/Assign_36',
#  u'save/restore_slice_37/tensor_name',
#  u'save/restore_slice_37/shape_and_slice',
#  u'save/restore_slice_37',
#  u'save/Assign_37',
#  u'save/restore_slice_38/tensor_name',
#  u'save/restore_slice_38/shape_and_slice',
#  u'save/restore_slice_38',
#  u'save/Assign_38',
#  u'save/restore_all']

# %%
epoch=5000
#change batch size according to your hardware's power. For GPU's use batch size in powers of 2 like 2,4,8,16...
batch_size=20 
previous_batch=0

# %%
for i in range(epoch):
    #batch wise training 
    if previous_batch >= len(X_train) : #total --> total number of training images
        previous_batch=0    
    current_batch=previous_batch+batch_size
    x_input=X_train[previous_batch:current_batch]
    x_images=np.reshape(x_input,[batch_size,56,56,3])
    y_input=Y_train[previous_batch:current_batch]
    y_label=np.reshape(y_input,[batch_size,2])
    previous_batch=previous_batch+batch_size
    _,loss=sess.run([train_step, cross_entropy], feed_dict={x: x_images,y_: y_label}) 
    if i%500==0:
        n=50 #number of test samples
        # increase the number of test samples with higher RAM. if you have less RAM, limit your test sample or 
        # run test accross larger samples once in every 1000 epochs or so..  
        x_test_images=np.reshape(X_test[0:n],[n,56,56,3])
        y_test_labels=np.reshape(Y_test[0:n],[n,2])
        Accuracy=sess.run(accuracy,
                           feed_dict={
                        x: x_test_images ,
                        y_: y_test_labels
                      })
        print "Iteration no :{} , Accuracy:{} , Loss : {}" .format(i,Accuracy,loss)
        saver.save(sess, save_path, global_step = i)
    elif i % 100 ==0:   
        print "Iteration no :{} Loss : {}" .format(i,loss)
# Out:
# Iteration no :0 , Accuracy:0.419999986887 , Loss : 0.700253307819
# Iteration no :100 Loss : 0.675329327583
# Iteration no :200 Loss : 0.586071133614
# Iteration no :300 Loss : 0.646527409554
# Iteration no :400 Loss : 0.61750125885
# Iteration no :500 , Accuracy:0.680000007153 , Loss : 0.639577746391
# Iteration no :600 Loss : 0.800202667713
# Iteration no :700 Loss : 0.776114106178
# Iteration no :800 Loss : 0.623359680176
# Iteration no :900 Loss : 0.333319067955
# Iteration no :1000 , Accuracy:0.800000011921 , Loss : 0.448847949505
# Iteration no :1100 Loss : 0.564746201038
# Iteration no :1200 Loss : 0.381719619036
# Iteration no :1300 Loss : 0.37440353632
# Iteration no :1400 Loss : 0.383201181889
# Iteration no :1500 , Accuracy:0.839999973774 , Loss : 0.692458629608
# Iteration no :1600 Loss : 0.513192117214
# Iteration no :1700 Loss : 0.347943484783
# Iteration no :1800 Loss : 0.476068109274
# Iteration no :1900 Loss : 0.34246096015
# Iteration no :2000 , Accuracy:0.899999976158 , Loss : 0.385148346424
# Iteration no :2100 Loss : 0.424253284931
# Iteration no :2200 Loss : 0.551398456097
# Iteration no :2300 Loss : 0.219499662519
# Iteration no :2400 Loss : 0.459910780191
# Iteration no :2500 , Accuracy:0.899999976158 , Loss : 0.441471517086
# Iteration no :2600 Loss : 0.482461512089
# Iteration no :2700 Loss : 0.559950053692
# Iteration no :2800 Loss : 0.321508586407
# Iteration no :2900 Loss : 0.459274202585
# Iteration no :3000 , Accuracy:0.839999973774 , Loss : 0.358123719692
# Iteration no :3100 Loss : 0.400708585978
# Iteration no :3200 Loss : 0.180358290672
# Iteration no :3300 Loss : 0.107370063663
# Iteration no :3400 Loss : 0.0927540510893
# Iteration no :3500 , Accuracy:0.819999992847 , Loss : 0.165898442268
# Iteration no :3600 Loss : 0.419696420431
# Iteration no :3700 Loss : 0.197618275881
# Iteration no :3800 Loss : 0.236401632428
# Iteration no :3900 Loss : 0.276552021503
# Iteration no :4000 , Accuracy:0.899999976158 , Loss : 0.402668952942
# Iteration no :4100 Loss : 0.202938273549
# Iteration no :4200 Loss : 0.0893388018012
# Iteration no :4300 Loss : 0.217578172684
# Iteration no :4400 Loss : 0.0168588850647
# Iteration no :4500 , Accuracy:0.899999976158 , Loss : 0.0872357264161
# Iteration no :4600 Loss : 0.271494448185
# Iteration no :4700 Loss : 0.0500963404775
# Iteration no :4800 Loss : 0.106963798404
# Iteration no :4900 Loss : 0.0311525464058

# %%
x_input=X_val
x_images=np.reshape(x_input,[len(X_val),56,56,3])
y_input=Y_val
y_label=np.reshape(y_input,[len(Y_val),2])

Accuracy_validation=sess.run(accuracy,
                           feed_dict={
                        x: x_images ,
                        y_: y_label
                      })

# %%
Accuracy_validation=round(Accuracy_validation*100,2)
print "Accuracy in the validation dataset: {} %" .format(Accuracy_validation)
# Out:
# Accuracy in the validation dataset: 79.76 %

# %%
def process_img(img):
        img=img.resize((56, 56), Image.ANTIALIAS) #resize the image
        img = np.array(img)
        img=img/np.max(img).astype(float) 
        img=np.reshape(img, [1,56,56,3])
        return img

# %%
#test your own images 
test_image=Image.open('/path to file')
test_image= process_img(test_image)
predicted_array= sess.run(y_predicted, feed_dict={x: test_image})
predicted_class= np.argmax(predicted_array)
if predicted_class==0:
    print "It is a cat"  
else :
    print "It is a dog  "
